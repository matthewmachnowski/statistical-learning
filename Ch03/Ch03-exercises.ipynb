# %% [markdown]
# # Chapter 3: Linear Regression — Exercises

# %% [markdown]
# ## Conceptual
#
# *Work through the conceptual exercises from the end of Chapter 3.*

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# ### Exercise 7

# %% [markdown]
# ## Applied
#
# *Work through the applied exercises from the end of Chapter 3.*

# %% [markdown]
# ### Exercise 8

# %% [markdown]
# ### Exercise 9

# %% [markdown]
# ### Exercise 10

# %% [markdown]
# ### Exercise 11

# %% [markdown]
# ### Exercise 12

# %% [markdown]
# ### Exercise 13

# %% [markdown]
# ### Exercise 14

# %% [markdown]
# ### Exercise 15
